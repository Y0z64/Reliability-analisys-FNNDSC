# %% [markdown]
# # Regional cortical thickness demo (left hemisphere)
#
# Quick proof-of-concept mapping **per-vertex cortical thickness** onto the
# **fetal21 regional atlas** (template-29 space) for a single example subject/split.
#
# - **Thickness** (`lh.smoothwm.native_81920.thk`) — one value per surface vertex.
# - **Regional atlas** (`lh.fetal21.1D.dset`) — one region label per vertex, same
#   40,962-vertex template mesh, so vertex *i* corresponds directly.
# - **Label names** (`21_annotation.csv`) — maps label id → ROI name + lobe.
#
# The subject's surfaces are registered to the template mesh, so the atlas label
# vector and the subject's thickness vector share the same vertex ordering and we
# can group thickness by region with a simple join. LH only — the atlas provided
# is left-hemisphere.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection  # noqa: F401 (registers 3d)

# --- paths (single example subject/split) ---
SUBJ  = ("/neuro/labs/grantlab/research/MRI_processing/seungyoon.jeong/2025/"
         "Reliability/TEST/FCB187/2022.06.10-MR-EI_Fetal_Neuro-26465115/S1")
ATLAS = "/neuro/users/mri.team/fetal_mri/Surface_template/template-29/old/lh.fetal21.1D.dset"
ANNOT = "/neuro/labs/grantlab/research/andrea.gondova/21_annotation.csv"
THK   = f"{SUBJ}/surfaces/lh.smoothwm.native_81920.thk"
OBJ   = f"{SUBJ}/surfaces/lh.smoothwm.native_81920.obj"

# %%
def read_mni_obj(path):
    """Parse a BIC/MNI `.obj` surface: returns (vertices[N,3], faces[M,3])."""
    with open(path) as f:
        t = f.read().split()
    assert t[0] == "P", "not a polygon .obj"
    n = int(t[6]); i = 7
    verts = np.array(t[i:i + 3 * n], dtype=float).reshape(n, 3); i += 3 * n
    i += 3 * n                       # skip per-vertex normals
    n_items = int(t[i]); i += 1
    colflag = int(t[i]); i += 1      # colour info block
    i += 4 if colflag == 0 else (4 * n_items if colflag == 1 else 4 * n)
    end = np.array(t[i:i + n_items], dtype=int); i += n_items
    conn = np.array(t[i:i + end[-1]], dtype=int)
    return verts, conn.reshape(n_items, 3)


labels = np.loadtxt(ATLAS).astype(int)      # (40962,) region id per vertex
thk    = np.loadtxt(THK)                     # (40962,) thickness (mm) per vertex
verts, faces = read_mni_obj(OBJ)             # geometry for rendering
annot  = pd.read_csv(ANNOT)

assert labels.shape == thk.shape == (verts.shape[0],), "vertex count mismatch!"
print(f"{len(thk):,} vertices | {faces.shape[0]:,} triangles | "
      f"{annot['label_21'].nunique()} atlas regions")
# Out:
# 40,962 vertices | 81,920 triangles | 22 atlas regions

# %%
lut = dict(zip(annot["label_21"], annot["ROI_21"]))
df = pd.DataFrame({"label": labels, "thickness": thk})
df["region"] = df["label"].map(lut)

# thickness == 0 marks vertices with no valid measure (e.g. medial wall); drop
valid = df[df["thickness"] > 0]
region_summary = (valid.groupby(["label", "region"])["thickness"]
                  .agg(mean="mean", std="std", n="count")
                  .reset_index()
                  .sort_values("mean", ascending=False))
region_summary.round(3)
# Out:
#     label                    region   mean    std     n
# 10     10  lateral occipital cortex  2.365  0.430  1400
# 7       7   inferior temporal gyrus  2.154  0.382  1255
# 6       6  inferior parietal cortex  2.051  0.477  1824
# 14     14     middle temporal gyrus  2.031  0.491  1422
# 3       3             cuneus cortex  1.965  0.414  1146
# 9       9          precuneus cortex  1.957  0.521  1770
# 5       5            fusiform gyrus  1.954  0.587  1262
# 17     17    inferior frontal gyrus  1.928  0.515  1356
# 1       1      middle frontal gyrus  1.924  0.519  2635
# 20     20       supramarginal gyrus  1.831  0.535  1359
# 13     13    superior frontal gyrus  1.784  0.450  3110
# 12     12             lingual gyrus  1.781  0.467  1494
# 18     18  superior parietal cortex  1.734  0.580  1838
# 21     21         postcentral gyrus  1.699  0.578  1968
# 16     16     parahippocampal gyrus  1.677  0.553   913
# 11     11     orbital frontal gyrus  1.671  0.521  1965
# 19     19   superior temporal gyrus  1.656  0.670  1946
# 4       4          precentral gyrus  1.624  0.642  2277
# 8       8                    insula  1.568  0.377  1802
# 2       2          cingulate cortex  1.559  0.519  1748
# 15     15        paracentral lobule  1.476  0.515   706
# 0       0             cingular pole  0.976  0.773  5766

# %% [markdown]
# ### Per-region mean thickness

# %%
fig, ax = plt.subplots(figsize=(8, 7))
rs = region_summary.sort_values("mean")
ax.barh(rs["region"], rs["mean"], xerr=rs["std"],
        color=plt.cm.viridis((rs["mean"] - rs["mean"].min()) /
                             (rs["mean"].max() - rs["mean"].min())),
        error_kw=dict(alpha=0.35, lw=0.8))
ax.set_xlabel("Cortical thickness (mm)")
ax.set_title("Mean regional thickness — FCB187 / S1 (LH)")
ax.margins(y=0.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Thickness mapped onto the cortical surface

# %%
def plot_surface(scalar, title, cmap="viridis", clip=(2, 98)):
    """Render the LH surface, colouring each triangle by mean vertex scalar."""
    face_vals = scalar[faces].mean(axis=1)
    vmin, vmax = np.percentile(scalar[scalar > 0], clip)
    fig = plt.figure(figsize=(13, 6))
    for k, (elev, azim, lab) in enumerate([(0, 180, "lateral"),
                                           (0, 0, "medial")]):
        ax = fig.add_subplot(1, 2, k + 1, projection="3d")
        tri = ax.plot_trisurf(verts[:, 0], verts[:, 1], verts[:, 2],
                              triangles=faces, cmap=cmap,
                              vmin=vmin, vmax=vmax, linewidth=0,
                              antialiased=False, shade=False)
        tri.set_array(face_vals)
        ax.view_init(elev=elev, azim=azim)
        ax.set_axis_off()
        ax.set_title(f"{lab} view")
        ax.set_box_aspect(np.ptp(verts, axis=0))
    fig.suptitle(title, y=0.98)
    cb = fig.colorbar(tri, ax=fig.axes, shrink=0.6, pad=0.02)
    cb.set_label("thickness (mm)")
    plt.show()


plot_surface(thk, "Per-vertex cortical thickness — FCB187 / S1 (LH)")

# %% [markdown]
# Same surface, but each vertex painted with its **region's mean thickness** — shows the atlas parcellation driving the regional summary above.

# %%
region_mean_lut = region_summary.set_index("label")["mean"].to_dict()
vertex_region_mean = np.array([region_mean_lut.get(l, 0.0) for l in labels])
plot_surface(vertex_region_mean,
             "Region-averaged thickness (atlas parcellation) — FCB187 / S1 (LH)")
